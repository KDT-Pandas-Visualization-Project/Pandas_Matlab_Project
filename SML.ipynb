# %%
import pandas as pd # 판다스 모듈 갖고오기
import numpy as np # 넘피 모듈 갖고오기
import matplotlib.pyplot as plt # pyplot 모듈 갖고오기
import matplotlib as mpl # matplotlib 패키지 갖고오기
import matplotlib.font_manager as fm # font_manager 갖고오기
import datetime as dt # datatime 모듈 갖고오기

import SampleData as d # SampleData.py의 변수 사용
import seaborn as sns

mpl.rcParams['font.family'] = 'AppleGothic'
# Out:
# English name
# UNKNOWN                                       14577
# Promise                                           5
# Spirit Guardians                                  5
# Meow Meow Japanese History                        4
# Cyborg 009                                        4
#                                               ...
# Astarotte's Toy EX                                1
# Persona 4 the Animation                           1
# Naruto Shippuden the Movie 5: Blood Prison        1
# Aria the Scarlet Ammo Special                     1
# The First Order                                   1
# Name: count, Length: 10134, dtype: int64 21352                                "Deji" Meets Girl
# 21298                                   "Ippon" again!
# 22847     "LIP×LIP" Interview Report by Hiyori Suzumi!
# 12434                                "Parade" de Satie
# 16413                                          "Star"t
#                              ...
# 721      xxxHOLiC The Movie: A Midsummer Night's Dream
# 24263                         Ōoku: The Inner Chambers
# 74                                            ∀ Gundam
# 3401                           ∀ Gundam I: Earth Light
# 3402                  ∀ Gundam II: Moonlight Butterfly
# Name: English name, Length: 24905, dtype: object

# %% [markdown]
# ## 0. 자료 출처 소개
# ## 0.1. 팀 공통 anime 2023 data set
# ## 0.2. 일본 영화 전체 흥행 순위
# ## 0.3. 한국 영화 전체 흥행 순위

# %%
anime = pd.read_csv("../Data/anime-dataset-2023.csv")
japanMovieRank = pd.read_excel("../Data/일본 내 영화 순위 2.xlsx", sheet_name='korean')
koreanMovieRank = pd.read_excel("../Data/한국 내 영화 순위.xlsx", header=None)

# %% [markdown]
# ## 1. 일본 영화 전체 흥행 순위 전처리

# %%
# 1.1. japanMovieRank 일본 영화 전체 흥행 순위 DataFrame 불러오기
japanMovieRank.head(20)
# Out:
#     순위                                 작품제목       배급사  흥행 수입(억 엔)        공개일  \
# 0    1                  극장판 '귀멸의 칼날' 무한 열차편  도호/애니플렉스       404.3 2020-10-16
# 1    2                         센과 치히로의 행방불명        도호       316.8 2001-07-20
# 2    3                                 타이타닉       FOX       277.7 1997-12-20
# 3    4                                 겨울왕국       디즈니       255.0 2014-03-14
# 4    5                              너의 이름은.        도호       251.7 2016-08-26
# 5    6                   ONE PIECE FILM RED       도에이       203.3 2022-08-06
# 6    7                         해리포터와 마법사의 돌        워너       203.0 2001-12-01
# 7    8                              모노노케 공주        도호       201.8 1997-07-12
# 8    9                           하울의 움직이는 성        도호       196.0 2004-11-20
# 9   10  춤추는 대수사선 THE MOVIE2 레인보우 브릿지를 봉쇄하라!        도호       173.5 2003-07-19
# 10  11                          해리포터와 비밀의 방        워너       173.0 2002-11-23
# 11  12                                  아바타       FOX       159.0 2009-12-23
# 12  13                  THE FIRST SLAM DUNK       도에이       157.3 2022-12-03
# 13  14                             절벽 위의 포뇨        도호       155.0 2008-07-19
# 14  15                              참새의 문단속        도호       149.4 2022-11-11
# 15  16                               날씨의 아이        도호       142.3 2019-07-19
# 16  17                     더 슈퍼 마리오 브라더스 무비     도호 도와       140.1 2023-04-28
# 17  18                   명탐정 코난 흑철의 물고기 그림자        도호       138.3 2023-04-14
# 18  19                           극장판 주술회전 0        도호       138.0 2021-12-24
# 19  20                               탑건 매버릭    동화 픽처스       137.7 2022-05-27
#
#    자국 영화                                         Unnamed: 6
# 0      *  1. 극장판 '귀멸의 칼날' 무한 열차편 - Demon Slayer: Mugen T...
# 1      *                    2. 센과 치히로의 행방불명 - Spirited Away
# 2    NaN                                  3. 타이타닉 - Titanic
# 3    NaN                                   4. 겨울왕국 - Frozen
# 4      *                            5. 너의 이름은. - Your Name.
# 5      *        6. ONE PIECE FILM RED - One Piece Film: Red
# 6    NaN  7. 해리포터와 마법사의 돌 - Harry Potter and the Sorcere...
# 7      *                     8. 모노노케 공주 - Princess Mononoke
# 8      *               9. 하울의 움직이는 성 - Howl's Moving Castle
# 9      *  10. 춤추는 대수사선 THE MOVIE2 레인보우 브릿지를 봉쇄하라! - Bays...
# 10   NaN  11. 해리포터와 비밀의 방 - Harry Potter and the Chamber...
# 11   NaN                                   12. 아바타 - Avatar
# 12     *      13. THE FIRST SLAM DUNK - The First Slam Dunk
# 13     *                               14. 절벽 위의 포뇨 - Ponyo
# 14     *  15. 참새의 문단속 - Sparrow's Hotel (Note: This migh...
# 15     *                   16. 날씨의 아이 - Weathering with You
# 16   NaN  17. 더 슈퍼 마리오 브라더스 무비 - The Super Mario Bros. M...
# 17     *  18. 명탐정 코난 흑철의 물고기 그림자 - Detective Conan: The ...
# 18     *       19. 극장판 주술회전 0 - Jujutsu Kaisen 0: The Movie
# 19   NaN                     20. 탑건 매버릭 - Top Gun: Maverick

# %%
# 1.2. 애니메이션 영화만 10개 추리기, 인덱스 다시 0부터 순차적으로 부여
jMR2 = japanMovieRank.iloc[[0,1,4,5,7,8,12,13,14,15]]
jMR2.reset_index(inplace=True)
jMR2
# Out:
#    index  순위                 작품제목       배급사  흥행 수입(억 엔)        공개일 자국 영화  \
# 0      0   1  극장판 '귀멸의 칼날' 무한 열차편  도호/애니플렉스       404.3 2020-10-16     *
# 1      1   2         센과 치히로의 행방불명        도호       316.8 2001-07-20     *
# 2      4   5              너의 이름은.        도호       251.7 2016-08-26     *
# 3      5   6   ONE PIECE FILM RED       도에이       203.3 2022-08-06     *
# 4      7   8              모노노케 공주        도호       201.8 1997-07-12     *
# 5      8   9           하울의 움직이는 성        도호       196.0 2004-11-20     *
# 6     12  13  THE FIRST SLAM DUNK       도에이       157.3 2022-12-03     *
# 7     13  14             절벽 위의 포뇨        도호       155.0 2008-07-19     *
# 8     14  15              참새의 문단속        도호       149.4 2022-11-11     *
# 9     15  16               날씨의 아이        도호       142.3 2019-07-19     *
#
#                                           Unnamed: 6
# 0  1. 극장판 '귀멸의 칼날' 무한 열차편 - Demon Slayer: Mugen T...
# 1                    2. 센과 치히로의 행방불명 - Spirited Away
# 2                            5. 너의 이름은. - Your Name.
# 3        6. ONE PIECE FILM RED - One Piece Film: Red
# 4                     8. 모노노케 공주 - Princess Mononoke
# 5               9. 하울의 움직이는 성 - Howl's Moving Castle
# 6      13. THE FIRST SLAM DUNK - The First Slam Dunk
# 7                               14. 절벽 위의 포뇨 - Ponyo
# 8  15. 참새의 문단속 - Sparrow's Hotel (Note: This migh...
# 9                   16. 날씨의 아이 - Weathering with You

# %% [markdown]
# ## 2. 한국 영화 전체 흥행 순위 전처리

# %%
# 2.1 koreanMovieRank 한국 내 애니 영화 전체 흥행 순위 DataFrame 불러오기
koreanMovieRank
# Out:
#      0                                       1      2           3           4
# 0   1위                                스즈메의 문단속  2022년     신카이 마코토  5,575,035명
# 1   2위                              더 퍼스트 슬램덩크  2022년   이노우에 다케히코  4,856,640명
# 2   3위                                 너의 이름은.  2016년     신카이 마코토  3,889,286명
# 3   4위                              하울의 움직이는 성  2004년    미야자키 하야오  3,015,165명
# 4   5위                       극장판 귀멸의 칼날: 무한열차편  2020년    소토자키 하루오  2,189,110명
# 5   6위                            센과 치히로의 행방불명  2001년    미야자키 하야오  2,167,573명
# 6   7위                          그대들은 어떻게 살 것인가  2023년    미야자키 하야오  2,011,871명
# 7   8위                                벼랑 위의 포뇨  2008년    미야자키 하야오  1,521,842명
# 8   9위                               마루 밑 아리에티  2010년  요네바야시 히로마사  1,086,004명
# 9  10위  신차원! 짱구는 못말려 더 무비: 초능력 대결전 ~날아라 수제김밥~   2023년     오오네 히토시    846,432명

# %%
# 2.2 KMR 내 컬럼명 추가하기
KMRcolumns = ['순위(kor)', '작품제목', '제작 연도(kor)', '감독(kor)', '관객 수(kor)']
koreanMovieRank.columns = KMRcolumns
koreanMovieRank
# Out:
#   순위(kor)                                    작품제목 제작 연도(kor)     감독(kor)  \
# 0      1위                                스즈메의 문단속      2022년     신카이 마코토
# 1      2위                              더 퍼스트 슬램덩크      2022년   이노우에 다케히코
# 2      3위                                 너의 이름은.      2016년     신카이 마코토
# 3      4위                              하울의 움직이는 성      2004년    미야자키 하야오
# 4      5위                       극장판 귀멸의 칼날: 무한열차편      2020년    소토자키 하루오
# 5      6위                            센과 치히로의 행방불명      2001년    미야자키 하야오
# 6      7위                          그대들은 어떻게 살 것인가      2023년    미야자키 하야오
# 7      8위                                벼랑 위의 포뇨      2008년    미야자키 하야오
# 8      9위                               마루 밑 아리에티      2010년  요네바야시 히로마사
# 9     10위  신차원! 짱구는 못말려 더 무비: 초능력 대결전 ~날아라 수제김밥~       2023년     오오네 히토시
#
#     관객 수(kor)
# 0  5,575,035명
# 1  4,856,640명
# 2  3,889,286명
# 3  3,015,165명
# 4  2,189,110명
# 5  2,167,573명
# 6  2,011,871명
# 7  1,521,842명
# 8  1,086,004명
# 9    846,432명

# %% [markdown]
# ## # 2.3 작품제목 통일하기

# %%
totalOuter = pd.merge(jMR2, koreanMovieRank, how = 'outer')
totalOuter
# Out:
#     index    순위                                    작품제목       배급사  흥행 수입(억 엔)  \
# 0     0.0   1.0                     극장판 '귀멸의 칼날' 무한 열차편  도호/애니플렉스       404.3
# 1     1.0   2.0                            센과 치히로의 행방불명        도호       316.8
# 2     4.0   5.0                                 너의 이름은.        도호       251.7
# 3     5.0   6.0                      ONE PIECE FILM RED       도에이       203.3
# 4     7.0   8.0                                 모노노케 공주        도호       201.8
# 5     8.0   9.0                              하울의 움직이는 성        도호       196.0
# 6    12.0  13.0                     THE FIRST SLAM DUNK       도에이       157.3
# 7    13.0  14.0                                절벽 위의 포뇨        도호       155.0
# 8    14.0  15.0                                 참새의 문단속        도호       149.4
# 9    15.0  16.0                                  날씨의 아이        도호       142.3
# 10    NaN   NaN                                스즈메의 문단속       NaN         NaN
# 11    NaN   NaN                              더 퍼스트 슬램덩크       NaN         NaN
# 12    NaN   NaN                       극장판 귀멸의 칼날: 무한열차편       NaN         NaN
# 13    NaN   NaN                          그대들은 어떻게 살 것인가       NaN         NaN
# 14    NaN   NaN                                벼랑 위의 포뇨       NaN         NaN
# 15    NaN   NaN                               마루 밑 아리에티       NaN         NaN
# 16    NaN   NaN  신차원! 짱구는 못말려 더 무비: 초능력 대결전 ~날아라 수제김밥~        NaN         NaN
#
#           공개일 자국 영화                                         Unnamed: 6  \
# 0  2020-10-16     *  1. 극장판 '귀멸의 칼날' 무한 열차편 - Demon Slayer: Mugen T...
# 1  2001-07-20     *                    2. 센과 치히로의 행방불명 - Spirited Away
# 2  2016-08-26     *                            5. 너의 이름은. - Your Name.
# 3  2022-08-06     *        6. ONE PIECE FILM RED - One Piece Film: Red
# 4  1997-07-12     *                     8. 모노노케 공주 - Princess Mononoke
# 5  2004-11-20     *               9. 하울의 움직이는 성 - Howl's Moving Castle
# 6  2022-12-03     *      13. THE FIRST SLAM DUNK - The First Slam Dunk
# 7  2008-07-19     *                               14. 절벽 위의 포뇨 - Ponyo
# 8  2022-11-11     *  15. 참새의 문단속 - Sparrow's Hotel (Note: This migh...
# 9  2019-07-19     *                   16. 날씨의 아이 - Weathering with You
# 10        NaT   NaN                                                NaN
# 11        NaT   NaN                                                NaN
# 12        NaT   NaN                                                NaN
# 13        NaT   NaN                                                NaN
# 14        NaT   NaN                                                NaN
# 15        NaT   NaN                                                NaN
# 16        NaT   NaN                                                NaN
#
#    순위(kor) 제작 연도(kor)     감독(kor)   관객 수(kor)
# 0      NaN        NaN         NaN         NaN
# 1       6위      2001년    미야자키 하야오  2,167,573명
# 2       3위      2016년     신카이 마코토  3,889,286명
# 3      NaN        NaN         NaN         NaN
# 4      NaN        NaN         NaN         NaN
# 5       4위      2004년    미야자키 하야오  3,015,165명
# 6      NaN        NaN         NaN         NaN
# 7      NaN        NaN         NaN         NaN
# 8      NaN        NaN         NaN         NaN
# 9      NaN        NaN         NaN         NaN
# 10      1위      2022년     신카이 마코토  5,575,035명
# 11      2위      2022년   이노우에 다케히코  4,856,640명
# 12      5위      2020년    소토자키 하루오  2,189,110명
# 13      7위      2023년    미야자키 하야오  2,011,871명
# 14      8위      2008년    미야자키 하야오  1,521,842명
# 15      9위      2010년  요네바야시 히로마사  1,086,004명
# 16     10위      2023년     오오네 히토시    846,432명

# %%
pd.merge(jMR2['작품제목'], koreanMovieRank['작품제목'], how = 'outer')
# Out:
#                                       작품제목
# 0                      극장판 '귀멸의 칼날' 무한 열차편
# 1                             센과 치히로의 행방불명
# 2                                  너의 이름은.
# 3                       ONE PIECE FILM RED
# 4                                  모노노케 공주
# 5                               하울의 움직이는 성
# 6                      THE FIRST SLAM DUNK
# 7                                 절벽 위의 포뇨
# 8                                  참새의 문단속
# 9                                   날씨의 아이
# 10                                스즈메의 문단속
# 11                              더 퍼스트 슬램덩크
# 12                       극장판 귀멸의 칼날: 무한열차편
# 13                          그대들은 어떻게 살 것인가
# 14                                벼랑 위의 포뇨
# 15                               마루 밑 아리에티
# 16  신차원! 짱구는 못말려 더 무비: 초능력 대결전 ~날아라 수제김밥~

# %%
'''
함수로 바꾸기
# iList = [0,6,8,7]
# jList = [4,1,0,7]
#
# while i < len(iList):
#
#     jMR2['작품제목'][iList[i]] = jMR2['작품제목'][iList[i]].replace(jMR2['작품제목'][iList[i]], koreanMovieRank['작품제목'][jList[j]])
#     i += 1
'''


iList = [0,6,8,7]
jList = [4,1,0,7]

for i, data in enumerate(iList):
    jMR2['작품제목'][data] = jMR2['작품제목'][data].replace(jMR2['작품제목'][data], koreanMovieRank['작품제목'][jList[i]])

# jMR2['작품제목'][6] = jMR2['작품제목'][6].replace(jMR2['작품제목'][6], koreanMovieRank['작품제목'][1])
# jMR2['작품제목'][8] = jMR2['작품제목'][8].replace(jMR2['작품제목'][8], koreanMovieRank['작품제목'][0])
# jMR2['작품제목'][7] = jMR2['작품제목'][7].replace(jMR2['작품제목'][7], koreanMovieRank['작품제목'][7])
# Out:
# /var/folders/9y/lpn0hjmn5csct06t4_r5qtjr0000gn/T/ipykernel_30896/4097695436.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jMR2['작품제목'][data] = jMR2['작품제목'][data].replace(jMR2['작품제목'][data], koreanMovieRank['작품제목'][jList[i]])
# /var/folders/9y/lpn0hjmn5csct06t4_r5qtjr0000gn/T/ipykernel_30896/4097695436.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jMR2['작품제목'][data] = jMR2['작품제목'][data].replace(jMR2['작품제목'][data], koreanMovieRank['작품제목'][jList[i]])
# /var/folders/9y/lpn0hjmn5csct06t4_r5qtjr0000gn/T/ipykernel_30896/4097695436.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jMR2['작품제목'][data] = jMR2['작품제목'][data].replace(jMR2['작품제목'][data], koreanMovieRank['작품제목'][jList[i]])
# /var/folders/9y/lpn0hjmn5csct06t4_r5qtjr0000gn/T/ipykernel_30896/4097695436.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jMR2['작품제목'][data] = jMR2['작품제목'][data].replace(jMR2['작품제목'][data], koreanMovieRank['작품제목'][jList[i]])

# %%
jMR2.info(),koreanMovieRank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       10 non-null     int64
#  1   순위          10 non-null     int64
#  2   작품제목        10 non-null     object
#  3   배급사         10 non-null     object
#  4   흥행 수입(억 엔)  10 non-null     float64
#  5   공개일         10 non-null     datetime64[ns]
#  6   자국 영화       10 non-null     object
#  7   Unnamed: 6  10 non-null     object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 772.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   순위(kor)     10 non-null     object
#  1   작품제목        10 non-null     object
#  2   제작 연도(kor)  10 non-null     object
#  3   감독(kor)     10 non-null     object
#  4   관객 수(kor)   10 non-null     object
# dtypes: object(5)
# memory usage: 532.0+ bytes
# (None, None)

# %%
jMR2
# Out:
#    index  순위                작품제목       배급사  흥행 수입(억 엔)        공개일 자국 영화  \
# 0      0   1   극장판 귀멸의 칼날: 무한열차편  도호/애니플렉스       404.3 2020-10-16     *
# 1      1   2        센과 치히로의 행방불명        도호       316.8 2001-07-20     *
# 2      4   5             너의 이름은.        도호       251.7 2016-08-26     *
# 3      5   6  ONE PIECE FILM RED       도에이       203.3 2022-08-06     *
# 4      7   8             모노노케 공주        도호       201.8 1997-07-12     *
# 5      8   9          하울의 움직이는 성        도호       196.0 2004-11-20     *
# 6     12  13          더 퍼스트 슬램덩크       도에이       157.3 2022-12-03     *
# 7     13  14            벼랑 위의 포뇨        도호       155.0 2008-07-19     *
# 8     14  15            스즈메의 문단속        도호       149.4 2022-11-11     *
# 9     15  16              날씨의 아이        도호       142.3 2019-07-19     *
#
#                                           Unnamed: 6
# 0  1. 극장판 '귀멸의 칼날' 무한 열차편 - Demon Slayer: Mugen T...
# 1                    2. 센과 치히로의 행방불명 - Spirited Away
# 2                            5. 너의 이름은. - Your Name.
# 3        6. ONE PIECE FILM RED - One Piece Film: Red
# 4                     8. 모노노케 공주 - Princess Mononoke
# 5               9. 하울의 움직이는 성 - Howl's Moving Castle
# 6      13. THE FIRST SLAM DUNK - The First Slam Dunk
# 7                               14. 절벽 위의 포뇨 - Ponyo
# 8  15. 참새의 문단속 - Sparrow's Hotel (Note: This migh...
# 9                   16. 날씨의 아이 - Weathering with You

# %%
totalInner = pd.merge(jMR2, koreanMovieRank, left_on="작품제목", right_on="작품제목")
totalInner
# Out:
#    index  순위               작품제목       배급사  흥행 수입(억 엔)        공개일 자국 영화  \
# 0      0   1  극장판 귀멸의 칼날: 무한열차편  도호/애니플렉스       404.3 2020-10-16     *
# 1      1   2       센과 치히로의 행방불명        도호       316.8 2001-07-20     *
# 2      4   5            너의 이름은.        도호       251.7 2016-08-26     *
# 3      8   9         하울의 움직이는 성        도호       196.0 2004-11-20     *
# 4     12  13         더 퍼스트 슬램덩크       도에이       157.3 2022-12-03     *
# 5     13  14           벼랑 위의 포뇨        도호       155.0 2008-07-19     *
# 6     14  15           스즈메의 문단속        도호       149.4 2022-11-11     *
#
#                                           Unnamed: 6 순위(kor) 제작 연도(kor)  \
# 0  1. 극장판 '귀멸의 칼날' 무한 열차편 - Demon Slayer: Mugen T...      5위      2020년
# 1                    2. 센과 치히로의 행방불명 - Spirited Away      6위      2001년
# 2                            5. 너의 이름은. - Your Name.      3위      2016년
# 3               9. 하울의 움직이는 성 - Howl's Moving Castle      4위      2004년
# 4      13. THE FIRST SLAM DUNK - The First Slam Dunk      2위      2022년
# 5                               14. 절벽 위의 포뇨 - Ponyo      8위      2008년
# 6  15. 참새의 문단속 - Sparrow's Hotel (Note: This migh...      1위      2022년
#
#      감독(kor)   관객 수(kor)
# 0   소토자키 하루오  2,189,110명
# 1   미야자키 하야오  2,167,573명
# 2    신카이 마코토  3,889,286명
# 3   미야자키 하야오  3,015,165명
# 4  이노우에 다케히코  4,856,640명
# 5   미야자키 하야오  1,521,842명
# 6    신카이 마코토  5,575,035명

# %%
total = totalInner[['작품제목', '순위', '순위(kor)', '흥행 수입(억 엔)', '제작 연도(kor)', '감독(kor)', '관객 수(kor)']]
total
# Out:
#                 작품제목  순위 순위(kor)  흥행 수입(억 엔) 제작 연도(kor)    감독(kor)   관객 수(kor)
# 0  극장판 귀멸의 칼날: 무한열차편   1      5위       404.3      2020년   소토자키 하루오  2,189,110명
# 1       센과 치히로의 행방불명   2      6위       316.8      2001년   미야자키 하야오  2,167,573명
# 2            너의 이름은.   5      3위       251.7      2016년    신카이 마코토  3,889,286명
# 3         하울의 움직이는 성   9      4위       196.0      2004년   미야자키 하야오  3,015,165명
# 4         더 퍼스트 슬램덩크  13      2위       157.3      2022년  이노우에 다케히코  4,856,640명
# 5           벼랑 위의 포뇨  14      8위       155.0      2008년   미야자키 하야오  1,521,842명
# 6           스즈메의 문단속  15      1위       149.4      2022년    신카이 마코토  5,575,035명

# %%
JAPTitleList = ['Kimetsu no Yaiba Movie: Mugen Ressha-hen',
             'Sen to Chihiro no Kamikakushi',
             'Kimi no Na wa.',
             'Howl no Ugoku Shiro',
             'The First Slam Dunk',
             'Gake no Ue no Ponyo',
             'Suzume no Tojimari'
             ]
total['Name'] = JAPTitleList
total
# Out:
# /var/folders/9y/lpn0hjmn5csct06t4_r5qtjr0000gn/T/ipykernel_30896/27747797.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total['Name'] = JAPTitleList
#                 작품제목  순위 순위(kor)  흥행 수입(억 엔) 제작 연도(kor)    감독(kor)  \
# 0  극장판 귀멸의 칼날: 무한열차편   1      5위       404.3      2020년   소토자키 하루오
# 1       센과 치히로의 행방불명   2      6위       316.8      2001년   미야자키 하야오
# 2            너의 이름은.   5      3위       251.7      2016년    신카이 마코토
# 3         하울의 움직이는 성   9      4위       196.0      2004년   미야자키 하야오
# 4         더 퍼스트 슬램덩크  13      2위       157.3      2022년  이노우에 다케히코
# 5           벼랑 위의 포뇨  14      8위       155.0      2008년   미야자키 하야오
# 6           스즈메의 문단속  15      1위       149.4      2022년    신카이 마코토
#
#     관객 수(kor)                                      Name
# 0  2,189,110명  Kimetsu no Yaiba Movie: Mugen Ressha-hen
# 1  2,167,573명             Sen to Chihiro no Kamikakushi
# 2  3,889,286명                            Kimi no Na wa.
# 3  3,015,165명                       Howl no Ugoku Shiro
# 4  4,856,640명                       The First Slam Dunk
# 5  1,521,842명                       Gake no Ue no Ponyo
# 6  5,575,035명                        Suzume no Tojimari

# %%
anime2 = anime[anime["Name"].isin(JAPTitleList)]

anime3 = pd.merge(total, anime2)
anime3
# Out:
#                 작품제목  순위 순위(kor)  흥행 수입(억 엔) 제작 연도(kor)    감독(kor)  \
# 0  극장판 귀멸의 칼날: 무한열차편   1      5위       404.3      2020년   소토자키 하루오
# 1       센과 치히로의 행방불명   2      6위       316.8      2001년   미야자키 하야오
# 2            너의 이름은.   5      3위       251.7      2016년    신카이 마코토
# 3         하울의 움직이는 성   9      4위       196.0      2004년   미야자키 하야오
# 4         더 퍼스트 슬램덩크  13      2위       157.3      2022년  이노우에 다케히코
# 5           벼랑 위의 포뇨  14      8위       155.0      2008년   미야자키 하야오
# 6           스즈메의 문단속  15      1위       149.4      2022년    신카이 마코토
#
#     관객 수(kor)                                      Name  anime_id  \
# 0  2,189,110명  Kimetsu no Yaiba Movie: Mugen Ressha-hen     40456
# 1  2,167,573명             Sen to Chihiro no Kamikakushi       199
# 2  3,889,286명                            Kimi no Na wa.     32281
# 3  3,015,165명                       Howl no Ugoku Shiro       431
# 4  4,856,640명                       The First Slam Dunk     45649
# 5  1,521,842명                       Gake no Ue no Ponyo      2890
# 6  5,575,035명                        Suzume no Tojimari     50594
#
#                                         English name  ...  \
# 0  Demon Slayer: Kimetsu no Yaiba - The Movie: Mu...  ...
# 1                                      Spirited Away  ...
# 2                                         Your Name.  ...
# 3                               Howl's Moving Castle  ...
# 4                                            UNKNOWN  ...
# 5                                              Ponyo  ...
# 6                                             Suzume  ...
#
#                                       Studios    Source     Duration  \
# 0                                    ufotable     Manga  1 hr 56 min
# 1                               Studio Ghibli  Original   2 hr 4 min
# 2                            CoMix Wave Films  Original  1 hr 46 min
# 3                               Studio Ghibli     Novel  1 hr 59 min
# 4  Toei Animation, DandeLion Animation Studio     Manga   2 hr 4 min
# 5                               Studio Ghibli  Original  1 hr 40 min
# 6                            CoMix Wave Films  Original   2 hr 1 min
#
#                            Rating   Rank Popularity Favorites  Scored By  \
# 0  R - 17+ (violence & profanity)   75.0         79     12766   923480.0
# 1                   PG - Children   36.0         44     31139  1234780.0
# 2       PG-13 - Teens 13 or older   27.0         11     87268  1807089.0
# 3                    G - All Ages   61.0         97     26858   866696.0
# 4       PG-13 - Teens 13 or older   73.0       4638       161     2456.0
# 5                    G - All Ages  689.0        374      3766   360594.0
# 6       PG-13 - Teens 13 or older  164.0        991      3120    81585.0
#
#    Members                                          Image URL
# 0  1399607  https://cdn.myanimelist.net/images/anime/1704/...
# 1  1760676  https://cdn.myanimelist.net/images/anime/6/795...
# 2  2597495  https://cdn.myanimelist.net/images/anime/5/870...
# 3  1253703  https://cdn.myanimelist.net/images/anime/5/758...
# 4    19419  https://cdn.myanimelist.net/images/anime/1745/...
# 5   542825  https://cdn.myanimelist.net/images/anime/7/897...
# 6   226369  https://cdn.myanimelist.net/images/anime/1598/...
#
# [7 rows x 31 columns]

# %%
anime3kor = []
anime3year = []
anime3cust = []

for i in anime3['순위(kor)']:
    anime3kor.append(i[0])
for i in anime3['제작 연도(kor)']:
    anime3year.append(i[:-1])
for i in anime3['관객 수(kor)']:
    i2 = i[:-1].replace(',','')
    anime3cust.append(i2)
    
    
anime3['한국순위'] = anime3kor
anime3['제작연도'] = anime3year
anime3['관객 수'] = anime3cust
# anime3['관객 수 ']

# %%
anime4 = anime3[['작품제목', 'Name', '순위', '한국순위', '흥행 수입(억 엔)', '제작연도', '감독(kor)', '관객 수', 'Genres', 'Rank', 'Favorites', 'Popularity', 'Members']]
anime4['한국순위'] = anime3['한국순위'].astype('int64')
anime4['제작연도'] = anime3['제작연도'].astype('int64')
anime4['관객 수'] = anime3['관객 수'].astype('int64')
anime4['Rank'] = anime3['Rank'].astype('float64')
anime4
# Out:
# /var/folders/9y/lpn0hjmn5csct06t4_r5qtjr0000gn/T/ipykernel_30896/648995850.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime4['한국순위'] = anime3['한국순위'].astype('int64')
# /var/folders/9y/lpn0hjmn5csct06t4_r5qtjr0000gn/T/ipykernel_30896/648995850.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime4['제작연도'] = anime3['제작연도'].astype('int64')
# /var/folders/9y/lpn0hjmn5csct06t4_r5qtjr0000gn/T/ipykernel_30896/648995850.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime4['관객 수'] = anime3['관객 수'].astype('int64')
# /var/folders/9y/lpn0hjmn5csct06t4_r5qtjr0000gn/T/ipykernel_30896/648995850.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anime4['Rank'] = anime3['Rank'].astype('float64')
#                 작품제목                                      Name  순위  한국순위  \
# 0  극장판 귀멸의 칼날: 무한열차편  Kimetsu no Yaiba Movie: Mugen Ressha-hen   1     5
# 1       센과 치히로의 행방불명             Sen to Chihiro no Kamikakushi   2     6
# 2            너의 이름은.                            Kimi no Na wa.   5     3
# 3         하울의 움직이는 성                       Howl no Ugoku Shiro   9     4
# 4         더 퍼스트 슬램덩크                       The First Slam Dunk  13     2
# 5           벼랑 위의 포뇨                       Gake no Ue no Ponyo  14     8
# 6           스즈메의 문단속                        Suzume no Tojimari  15     1
#
#    흥행 수입(억 엔)  제작연도    감독(kor)     관객 수  \
# 0       404.3  2020   소토자키 하루오  2189110
# 1       316.8  2001   미야자키 하야오  2167573
# 2       251.7  2016    신카이 마코토  3889286
# 3       196.0  2004   미야자키 하야오  3015165
# 4       157.3  2022  이노우에 다케히코  4856640
# 5       155.0  2008   미야자키 하야오  1521842
# 6       149.4  2022    신카이 마코토  5575035
#
#                                               Genres   Rank  Favorites  \
# 0                                    Action, Fantasy   75.0      12766
# 1             Adventure, Award Winning, Supernatural   36.0      31139
# 2                 Award Winning, Drama, Supernatural   27.0      87268
# 3  Adventure, Award Winning, Drama, Fantasy, Romance   61.0      26858
# 4                              Award Winning, Sports   73.0        161
# 5                  Adventure, Award Winning, Fantasy  689.0       3766
# 6                                 Adventure, Fantasy  164.0       3120
#
#    Popularity  Members
# 0          79  1399607
# 1          44  1760676
# 2          11  2597495
# 3          97  1253703
# 4        4638    19419
# 5         374   542825
# 6         991   226369

# %%
anime4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   작품제목        7 non-null      object
#  1   Name        7 non-null      object
#  2   순위          7 non-null      int64
#  3   한국순위        7 non-null      int64
#  4   흥행 수입(억 엔)  7 non-null      float64
#  5   제작연도        7 non-null      int64
#  6   감독(kor)     7 non-null      object
#  7   관객 수        7 non-null      int64
#  8   Genres      7 non-null      object
#  9   Rank        7 non-null      float64
#  10  Favorites   7 non-null      int64
#  11  Popularity  7 non-null      int64
#  12  Members     7 non-null      int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 860.0+ bytes

# %%
anime4.sort_values('순위', ascending=1)
# Out:
#                 작품제목                                      Name  순위  한국순위  \
# 0  극장판 귀멸의 칼날: 무한열차편  Kimetsu no Yaiba Movie: Mugen Ressha-hen   1     5
# 1       센과 치히로의 행방불명             Sen to Chihiro no Kamikakushi   2     6
# 2            너의 이름은.                            Kimi no Na wa.   5     3
# 3         하울의 움직이는 성                       Howl no Ugoku Shiro   9     4
# 4         더 퍼스트 슬램덩크                       The First Slam Dunk  13     2
# 5           벼랑 위의 포뇨                       Gake no Ue no Ponyo  14     8
# 6           스즈메의 문단속                        Suzume no Tojimari  15     1
#
#    흥행 수입(억 엔)  제작연도    감독(kor)     관객 수  \
# 0       404.3  2020   소토자키 하루오  2189110
# 1       316.8  2001   미야자키 하야오  2167573
# 2       251.7  2016    신카이 마코토  3889286
# 3       196.0  2004   미야자키 하야오  3015165
# 4       157.3  2022  이노우에 다케히코  4856640
# 5       155.0  2008   미야자키 하야오  1521842
# 6       149.4  2022    신카이 마코토  5575035
#
#                                               Genres   Rank  Favorites  \
# 0                                    Action, Fantasy   75.0      12766
# 1             Adventure, Award Winning, Supernatural   36.0      31139
# 2                 Award Winning, Drama, Supernatural   27.0      87268
# 3  Adventure, Award Winning, Drama, Fantasy, Romance   61.0      26858
# 4                              Award Winning, Sports   73.0        161
# 5                  Adventure, Award Winning, Fantasy  689.0       3766
# 6                                 Adventure, Fantasy  164.0       3120
#
#    Popularity  Members
# 0          79  1399607
# 1          44  1760676
# 2          11  2597495
# 3          97  1253703
# 4        4638    19419
# 5         374   542825
# 6         991   226369

# %%
anime4.sort_values('한국순위', ascending=1)
# Out:
#                 작품제목                                      Name  순위  한국순위  \
# 6           스즈메의 문단속                        Suzume no Tojimari  15     1
# 4         더 퍼스트 슬램덩크                       The First Slam Dunk  13     2
# 2            너의 이름은.                            Kimi no Na wa.   5     3
# 3         하울의 움직이는 성                       Howl no Ugoku Shiro   9     4
# 0  극장판 귀멸의 칼날: 무한열차편  Kimetsu no Yaiba Movie: Mugen Ressha-hen   1     5
# 1       센과 치히로의 행방불명             Sen to Chihiro no Kamikakushi   2     6
# 5           벼랑 위의 포뇨                       Gake no Ue no Ponyo  14     8
#
#    흥행 수입(억 엔)  제작연도    감독(kor)     관객 수  \
# 6       149.4  2022    신카이 마코토  5575035
# 4       157.3  2022  이노우에 다케히코  4856640
# 2       251.7  2016    신카이 마코토  3889286
# 3       196.0  2004   미야자키 하야오  3015165
# 0       404.3  2020   소토자키 하루오  2189110
# 1       316.8  2001   미야자키 하야오  2167573
# 5       155.0  2008   미야자키 하야오  1521842
#
#                                               Genres   Rank  Favorites  \
# 6                                 Adventure, Fantasy  164.0       3120
# 4                              Award Winning, Sports   73.0        161
# 2                 Award Winning, Drama, Supernatural   27.0      87268
# 3  Adventure, Award Winning, Drama, Fantasy, Romance   61.0      26858
# 0                                    Action, Fantasy   75.0      12766
# 1             Adventure, Award Winning, Supernatural   36.0      31139
# 5                  Adventure, Award Winning, Fantasy  689.0       3766
#
#    Popularity  Members
# 6         991   226369
# 4        4638    19419
# 2          11  2597495
# 3          97  1253703
# 0          79  1399607
# 1          44  1760676
# 5         374   542825

# %%
# def animeFunc(a,b):
#     plt.figure(figsize=(5,5))
#     plt.bar(anime4[a],anime4[b])
#     plt.xlabel(a)
#     plt.ylabel(b)
#     plt.title(a '/' b)
#     plt.show()
    
    
# animeFunc('흥행 수입(억 엔)')
# # animeFunc('관객 수')
# # animeFunc('Rank')
# # animeFunc('Favorites')
# # animeFunc('Popularity')
# # animeFunc('Members')

# %%
# df.set_index('Category', inplace=True)
anime5 = anime4.set_index('작품제목')
# ax = anime5.plot(kind='bar')
anime5
# Out:
#                                                        Name  순위  한국순위  \
# 작품제목
# 극장판 귀멸의 칼날: 무한열차편  Kimetsu no Yaiba Movie: Mugen Ressha-hen   1     5
# 센과 치히로의 행방불명                  Sen to Chihiro no Kamikakushi   2     6
# 너의 이름은.                                      Kimi no Na wa.   5     3
# 하울의 움직이는 성                              Howl no Ugoku Shiro   9     4
# 더 퍼스트 슬램덩크                              The First Slam Dunk  13     2
# 벼랑 위의 포뇨                                Gake no Ue no Ponyo  14     8
# 스즈메의 문단속                                 Suzume no Tojimari  15     1
#
#                    흥행 수입(억 엔)  제작연도    감독(kor)     관객 수  \
# 작품제목
# 극장판 귀멸의 칼날: 무한열차편       404.3  2020   소토자키 하루오  2189110
# 센과 치히로의 행방불명            316.8  2001   미야자키 하야오  2167573
# 너의 이름은.                 251.7  2016    신카이 마코토  3889286
# 하울의 움직이는 성              196.0  2004   미야자키 하야오  3015165
# 더 퍼스트 슬램덩크              157.3  2022  이노우에 다케히코  4856640
# 벼랑 위의 포뇨                155.0  2008   미야자키 하야오  1521842
# 스즈메의 문단속                149.4  2022    신카이 마코토  5575035
#
#                                                               Genres   Rank  \
# 작품제목
# 극장판 귀멸의 칼날: 무한열차편                                    Action, Fantasy   75.0
# 센과 치히로의 행방불명                  Adventure, Award Winning, Supernatural   36.0
# 너의 이름은.                           Award Winning, Drama, Supernatural   27.0
# 하울의 움직이는 성         Adventure, Award Winning, Drama, Fantasy, Romance   61.0
# 더 퍼스트 슬램덩크                                     Award Winning, Sports   73.0
# 벼랑 위의 포뇨                           Adventure, Award Winning, Fantasy  689.0
# 스즈메의 문단속                                          Adventure, Fantasy  164.0
#
#                    Favorites  Popularity  Members
# 작품제목
# 극장판 귀멸의 칼날: 무한열차편      12766          79  1399607
# 센과 치히로의 행방불명           31139          44  1760676
# 너의 이름은.                87268          11  2597495
# 하울의 움직이는 성             26858          97  1253703
# 더 퍼스트 슬램덩크               161        4638    19419
# 벼랑 위의 포뇨                3766         374   542825
# 스즈메의 문단속                3120         991   226369

# %%
anime4.to_csv('anime4.csv', index=False)

# %%
anime_year = anime5['제작연도'].value_counts().sort_index()

plt.figure(figsize=(4, 3))
anime_year.plot(kind='bar')
plt.xlabel('Production Year')
plt.ylabel('Number of Anime')
plt.title('Number of Anime per Production Year')
plt.xticks(rotation=45)
plt.show()

# %%
anime_director = anime5['감독(kor)'].value_counts()

top_directors = anime_director.head(10)

# Plotting
plt.figure(figsize=(4, 3))
top_directors.plot(kind='bar')
plt.xlabel('Director')
plt.ylabel('Number of Anime')
plt.title('Number of Anime per Director (Top 10)')
plt.xticks(rotation=45)
plt.show()

# %%
# def plotting(a,b,c,d,e):
#     plt.figure(figsize=(4, 3))
#     anime_per_year.plot(kind='bar')
#     plt.xlabel('Production Year')
#     plt.ylabel('Number of Anime')
#     plt.title('Number of Anime per Production Year')
#     plt.xticks(rotation=45)
#     plt.show()

# %%
sns_columns = ['흥행 수입(억 엔)', '관객 수', 'Rank', 'Favorites', 'Popularity', 'Members']
selected_anime5 = anime5[sns_columns]

# Plotting pairplot for the selected columns
sns.pairplot(selected_anime5)
plt.show()
# Out:
# /Users/sml/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
anime5Corr = anime5.corr(numeric_only=True)
anime5Corr
# Out:
#                   순위      한국순위  흥행 수입(억 엔)      제작연도      관객 수      Rank  \
# 순위          1.000000 -0.278028   -0.947781  0.265628  0.482785  0.531101
# 한국순위       -0.278028  1.000000    0.291491 -0.666723 -0.962330  0.605626
# 흥행 수입(억 엔) -0.947781  0.291491    1.000000 -0.089200 -0.490363 -0.424245
# 제작연도        0.265628 -0.666723   -0.089200  1.000000  0.666879 -0.159561
# 관객 수        0.482785 -0.962330   -0.490363  0.666879  1.000000 -0.410292
# Rank        0.531101  0.605626   -0.424245 -0.159561 -0.410292  1.000000
# Favorites  -0.502412 -0.068859    0.273364 -0.185445 -0.027867 -0.398808
# Popularity  0.490454 -0.470542   -0.455083  0.515614  0.558445 -0.095485
# Members    -0.790319  0.201032    0.611731 -0.361134 -0.351968 -0.403664
#
#             Favorites  Popularity   Members
# 순위          -0.502412    0.490454 -0.790319
# 한국순위        -0.068859   -0.470542  0.201032
# 흥행 수입(억 엔)   0.273364   -0.455083  0.611731
# 제작연도        -0.185445    0.515614 -0.361134
# 관객 수        -0.027867    0.558445 -0.351968
# Rank        -0.398808   -0.095485 -0.403664
# Favorites    1.000000   -0.438904  0.904515
# Popularity  -0.438904    1.000000 -0.656623
# Members      0.904515   -0.656623  1.000000

# %%
sns.heatmap(anime5Corr, annot=True)
# Out:
# /Users/sml/anaconda3/lib/python3.11/site-packages/seaborn/utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <Axes: >
# /Users/sml/anaconda3/lib/python3.11/site-packages/IPython/core/events.py:93: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# /Users/sml/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
def animeFunc(a,b):
    plt.figure(figsize=(5,5))
    colorList = ['#008080', '#3CB371', '#7FFF00', '#FFD700', '#FFA500', '#FF4500', '#DA70D6']
    plt.bar(anime4[a],anime4[b], color=colorList)
    plt.xlabel(a)
    plt.ylabel(b)
    plt.title(a + '/' + b)
#     plt.legend(i for i in list(anime5.index))
#     plt.legend('극장판 귀멸의 칼날: 무한열차편', '센과 치히로의 행방불명', '너의 이름은.', '하울의 움직이는 성', '더 퍼스트 슬램덩크', '벼랑 위의 포뇨', '스즈메의 문단속')
#     box = {'facecolor':'white', 'edgecolor' : 'white'}
#     box1 = {'facecolor' : 'red', 'edgecolor' : 'white'}
#     plt.text(12, 400, '극장판 귀멸의 칼날: 무한열차편', bbox=box)
#     plt.text(11.5, 400, ' ', bbox=box1)
#     box2 = {'facecolor' : 'orange', 'edgecolor' : 'white'}
#     plt.text(12, 385, '센과 치히로의 행방불명', bbox=box)
#     plt.text(11.5, 385, ' ', bbox=box2)    
#     box3 = {'facecolor' : 'yellow', 'edgecolor' : 'white'}
#     plt.text(12, 370, '너의 이름은.', bbox=box)
#     plt.text(11.5, 370, ' ', bbox=box3) 
#     box4 = {'facecolor' : 'green', 'edgecolor' : 'white'}
#     plt.text(12, 355, '하울의 움직이는 성', bbox=box)
#     plt.text(11.5, 355, ' ', bbox=box4) 
#     box5 = {'facecolor' : 'blue', 'edgecolor' : 'white'}
#     plt.text(12, 340, '더 퍼스트 슬램덩크', bbox=box)
#     plt.text(11.5, 340, ' ', bbox=box5) 
#     box6 = {'facecolor' : 'indigo', 'edgecolor' : 'white'}
#     plt.text(12, 325, '벼랑 위의 포뇨', bbox=box)
#     plt.text(11.5, 325, ' ', bbox=box6)     
#     box7 = {'facecolor' : 'purple', 'edgecolor' : 'white'}
#     plt.text(12, 310, '스즈메의 문단속', bbox=box)
#     plt.text(11.5, 310, ' ', bbox=box7)       
# #     plt.text(12, 400, '극장판 귀멸의 칼날: 무한열차편', bbox=box)
# #     plt.text(11.5, 400, ' ', bbox=box1)
    plt.show()
    
    
animeFunc('Members', 'Favorites')

# %%
type(anime5.index)
# Out:
# pandas.core.indexes.base.Index

# %%
list(anime5.index)
# Out:
# ['극장판 귀멸의 칼날: 무한열차편',
#  '센과 치히로의 행방불명',
#  '너의 이름은.',
#  '하울의 움직이는 성',
#  '더 퍼스트 슬램덩크',
#  '벼랑 위의 포뇨',
#  '스즈메의 문단속']

# %%
animeFunc('한국순위', 'Popularity')

# %%
animeFunc('한국순위', '관객 수')

# %%
animeFunc('순위', 'Favorites')

# %%
animeFunc('제작연도', '한국순위')

# %%
animeFunc('한국순위', 'Popularity')
